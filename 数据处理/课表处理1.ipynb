# %%
import pandas as pd
import icalendar
import re
from datetime import datetime

# 指定.ics文件路径
ics_file_path = '../Data/课表/li/2022秋li.ics'

# 打开.ics文件
with open(ics_file_path, 'rb') as file:
    # 读取文件内容
    content = file.read()

    # 创建空的字典
    events = []
    
    # 解析.ics文件
    calendar = icalendar.Calendar.from_ical(content)

    # 遍历事件
    for event in calendar.walk('VEVENT'):
        # 提取事件信息
        summary = event.get('SUMMARY')
        start_time = event.get('DTSTART').dt
        end_time = event.get('DTEND').dt
        description = event.get('DESCRIPTION').split('\n')
        
        # 去除特殊字符
        split_des = [item.replace('&nbsp;', '') for item in description]
        
        # 提取RRULE属性
        rrule = event.get('RRULE')

        # 判断事件是否包含RRULE属性
        if rrule is not None:
            # 提取RRULE中的周数信息
            freq = rrule.get('FREQ')
            until = rrule.get('UNTIL')
            interval = rrule.get('INTERVAL')
        
        start_date = start_time.date()
        
        # 获取星期几
        weekday = start_date.strftime('%A')
        
        # 判断UNTIL属性是否为列表
        if isinstance(until, list):
            # 遍历列表中的元素
            for element in until:
                # 提取结束日期
                end_date = element
        else:
            # 提取结束日期
            end_date = until.date()
        
        # 提取小时和分钟部分
        formatted_start_time = start_time.strftime('%H:%M')
        formatted_end_time = end_time.strftime('%H:%M')

        # 将事件信息添加到DataFrame中
        event_dict = {'Summary': summary, 'Start Date': start_date, 'End Date': end_date, 'Weekday': weekday,\
                      'Start Time': formatted_start_time,'End Time': formatted_end_time, 'Node': split_des[0],\
                      'Location': split_des[1], 'Teacher': split_des[2]}
        events.append(event_dict)
    df = pd.DataFrame(events)
    
df
# Out:
#                      Summary  Start Date                  End Date    Weekday  \
# 0                       基本乐理  2022-08-30 2022-10-24 16:00:00+00:00    Tuesday
# 1       毛泽东思想和中国特色社会主义理论体系概论  2022-08-23 2022-12-19 16:00:00+00:00    Tuesday
# 2                      宏观经济学  2022-09-20 2022-12-19 16:00:00+00:00    Tuesday
# 3                       国际商务  2022-10-20 2022-10-26 16:00:00+00:00   Thursday
# 4                       国际商务  2022-10-13 2022-10-19 16:00:00+00:00   Thursday
# 5                       国际商务  2022-08-25 2022-09-21 16:00:00+00:00   Thursday
# 6                       国际商务  2022-09-29 2022-10-05 16:00:00+00:00   Thursday
# 7                       国际商务  2022-09-22 2022-09-28 16:00:00+00:00   Thursday
# 8                 管理信息系统(实验)  2022-09-29 2022-11-02 16:00:00+00:00   Thursday
# 9       毛泽东思想和中国特色社会主义理论体系概论  2022-08-25 2022-12-21 16:00:00+00:00   Thursday
# 10                    领导力与沟通  2022-10-27 2022-12-21 16:00:00+00:00   Thursday
# 11                      国际商务  2022-10-17 2022-10-23 16:00:00+00:00     Monday
# 12                      国际商务  2022-09-19 2022-09-25 16:00:00+00:00     Monday
# 13                      国际商务  2022-10-10 2022-10-16 16:00:00+00:00     Monday
# 14                      国际商务  2022-08-22 2022-09-18 16:00:00+00:00     Monday
# 15                      国际商务  2022-09-26 2022-10-02 16:00:00+00:00     Monday
# 16                    管理信息系统  2022-09-05 2022-09-11 16:00:00+00:00     Monday
# 17                    管理信息系统  2022-09-12 2022-10-30 16:00:00+00:00     Monday
# 18                    管理信息系统  2022-08-29 2022-09-04 16:00:00+00:00     Monday
# 19                      战略管理  2022-08-22 2022-10-23 16:00:00+00:00     Monday
# 20  毛泽东思想和中国特色社会主义理论体系概论(实验)  2022-10-29 2022-11-04 16:00:00+00:00   Saturday
# 21                 体育(软式曲棍球)  2022-08-26 2022-12-15 16:00:00+00:00     Friday
# 22                    管理信息系统  2022-09-09 2022-09-15 16:00:00+00:00     Friday
# 23                    管理信息系统  2022-09-02 2022-09-08 16:00:00+00:00     Friday
# 24                    管理信息系统  2022-09-16 2022-11-03 16:00:00+00:00     Friday
# 25                     宏观经济学  2022-09-23 2022-12-22 16:00:00+00:00     Friday
# 26                 概率论与数理统计C  2022-08-26 2022-11-24 16:00:00+00:00     Friday
# 27                 概率论与数理统计C  2022-08-24 2022-11-22 16:00:00+00:00  Wednesday
# 28                学术英语综合(提高)  2022-08-24 2022-12-13 16:00:00+00:00  Wednesday
# 29                      战略管理  2022-08-24 2022-10-25 16:00:00+00:00  Wednesday
#
#    Start Time End Time      Node  Location             Teacher
# 0       18:30    22:15  第9 - 12节    正心122                  范美娟
# 1       08:00    09:45   第1 - 2节    正心414                  黄钰婉
# 2       13:45    15:30   第5 - 6节    正心332                   王玲
# 3       10:00    11:45   第3 - 4节     正心320                 王雅杰
# 4       10:00    11:45   第3 - 4节     正心320                 王雅杰
# 5       10:00    11:45   第3 - 4节     正心320                 姜明辉
# 6       10:00    11:45   第3 - 4节     正心320                 王雅杰
# 7       10:00    11:45   第3 - 4节     正心320                 王雅杰
# 8       15:45    17:30   第7 - 8节      G002                  邵真
# 9       13:45    15:30   第5 - 6节     正心414                 黄钰婉
# 10      08:00    11:45   第1 - 4节     正心303                  叶蔓
# 11      13:45    15:30   第5 - 6节     正心320                 王雅杰
# 12      13:45    15:30   第5 - 6节     正心320                 王雅杰
# 13      13:45    15:30   第5 - 6节     正心320                 王雅杰
# 14      13:45    15:30   第5 - 6节     正心320                 姜明辉
# 15      13:45    15:30   第5 - 6节     正心320                 王雅杰
# 16      15:45    17:30   第7 - 8节      正心21                 冯玉强
# 17      15:45    17:30   第7 - 8节      正心21                  邵真
# 18      15:45    17:30   第7 - 8节      正心21                 冯玉强
# 19      08:00    09:45   第1 - 2节     正心310                  王民
# 20      15:45    17:30   第7 - 8节     正心117                 黄钰婉
# 21      10:00    11:45   第3 - 4节                            徐磊
# 22      13:45    15:30   第5 - 6节   正心21     Douglas Rudy Vogel
# 23      13:45    15:30   第5 - 6节   正心21                    冯玉强
# 24      13:45    15:30   第5 - 6节   正心21                     邵真
# 25      15:45    17:30   第7 - 8节  正心332                     王玲
# 26      08:00    09:45   第1 - 2节   致知41                     王力
# 27      13:45    15:30   第5 - 6节      致知41                  王力
# 28      10:00    11:45   第3 - 4节     正心303                 杨莉萍
# 29      08:00    09:45   第1 - 2节     正心310                  王民

# %%
df.to_csv('../temp/final/li/2022_autumn.csv' , sep= ',', encoding='gbk',index=False)
