# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def load_data(file_name):
    df = pd.read_csv("D:/大创/Data/" + file_name ,encoding='gbk')
    columns = df.columns
    df.fillna(df.mean(numeric_only=True) ,inplace=True)
    return df

# %%
df = load_data('lai.csv')
df.loc[:590]
# Out:
#             学工号   姓名    交易额             商户名称       交易日期   交易时间   星期
# 0    2021****86  赖**   8.90           淘乐学苑水果  2023/4/25  18:02  星期二
# 1    2021****86  赖**  11.84       美食林小猪憨尼麻辣烫  2023/4/25  17:35  星期二
# 2    2021****86  赖**  13.00         美食林川蜀源烤鱼  2023/4/25  11:46  星期二
# 3    2021****86  赖**   2.65         学苑食堂副食一组  2023/4/25   7:49  星期二
# 4    2021****86  赖**  18.40      紫丁香餐吧机器人收银组  2023/4/24  17:57  星期一
# ..          ...  ...    ...              ...        ...    ...  ...
# 586  2021****86  赖**   5.00           淘乐学苑水果  2022/7/13  18:05  星期三
# 587  2021****86  赖**  11.00         美食林老上客砂锅  2022/7/13  18:03  星期三
# 588  2021****86  赖**   4.00        学苑食堂霞姐饮品店  2022/7/13  12:21  星期三
# 589  2021****86  赖**  12.00  美食林蜀香麻辣烫(川香麻辣烫)  2022/7/13  11:55  星期三
# 590  2021****86  赖**  31.00        中央红小月亮门店5  2022/7/11  17:45  星期一
#
# [591 rows x 7 columns]

# %%
abnormal_merchant = np.array(['淘乐学苑水果','学苑食堂霞姐饮品店','中央红小月亮门店5','中央红小月亮门店2'\
                             ,'中央红小月亮门店4','中央红小月亮门店6','中央红小月亮门店3','中央红小月亮正心楼'\
                             ,'中央红-水果','哈尔滨市南岗区淘乐水果捞店','中央红小月亮门店1','中央红-药店'\
                             ,'深澜网费对接','中央红-辣货','紫丁香餐吧酒水（聚鑫食品）','回味斋一餐厅酒水组'\
                             ,'美芝林快客','灌制间'])
abnormal_merchant
# Out:
# array(['淘乐学苑水果', '学苑食堂霞姐饮品店', '中央红小月亮门店5', '中央红小月亮门店2', '中央红小月亮门店4',
#        '中央红小月亮门店6', '中央红小月亮门店3', '中央红小月亮正心楼', '中央红-水果', '哈尔滨市南岗区淘乐水果捞店',
#        '中央红小月亮门店1', '中央红-药店', '深澜网费对接', '中央红-辣货', '紫丁香餐吧酒水（聚鑫食品）',
#        '回味斋一餐厅酒水组', '美芝林快客', '灌制间'], dtype='<U13')

# %%
merchant = df['商户名称'][:591]
df = df[:591]

for i,m in enumerate(merchant):
    if m in abnormal_merchant:
        df = df.drop([i])
    else:
        pass
        
df
# Out:
#             学工号   姓名    交易额             商户名称       交易日期   交易时间   星期
# 1    2021****86  赖**  11.84       美食林小猪憨尼麻辣烫  2023/4/25  17:35  星期二
# 2    2021****86  赖**  13.00         美食林川蜀源烤鱼  2023/4/25  11:46  星期二
# 3    2021****86  赖**   2.65         学苑食堂副食一组  2023/4/25   7:49  星期二
# 4    2021****86  赖**  18.40      紫丁香餐吧机器人收银组  2023/4/24  17:57  星期一
# 5    2021****86  赖**  18.40      紫丁香餐吧机器人收银组  2023/4/24  11:27  星期一
# ..          ...  ...    ...              ...        ...    ...  ...
# 582  2021****86  赖**   3.50         学苑食堂副食三组  2022/7/15   7:24  星期五
# 584  2021****86  赖**  12.00  美食林蜀香麻辣烫(川香麻辣烫)  2022/7/14  17:48  星期四
# 585  2021****86  赖**   5.25         学苑食堂副食三组  2022/7/14   7:30  星期四
# 587  2021****86  赖**  11.00         美食林老上客砂锅  2022/7/13  18:03  星期三
# 589  2021****86  赖**  12.00  美食林蜀香麻辣烫(川香麻辣烫)  2022/7/13  11:55  星期三
#
# [477 rows x 7 columns]

# %%
df.to_csv('D:/大创/temp/赖（去异常1）.csv',sep= ',', encoding='gbk',index=False)
